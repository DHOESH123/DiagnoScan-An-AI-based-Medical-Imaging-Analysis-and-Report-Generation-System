# %%
import os
import glob
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# ------------------------------
# Config
# ------------------------------
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 30
SEED = 42
NUM_SAMPLES = 5000   # total samples to use
BALANCE = True       # keep balanced positives & negatives

# Paths (update to your dataset paths)
IMAGE_DIR = "/content/drive/MyDrive/archive (7)/siim-acr-pneumothorax/png_images"
MASK_DIR  = "/content/drive/MyDrive/archive (7)/siim-acr-pneumothorax/png_masks"

MODEL_NAME = "unet_pneumo_grayscale_5000.keras"

# ------------------------------
# Collect file paths
# ------------------------------
x_all = sorted(glob.glob(os.path.join(IMAGE_DIR, "*.png")))
y_all = sorted(glob.glob(os.path.join(MASK_DIR, "*.png")))

print("Total images:", len(x_all))
print("Total masks:", len(y_all))

if len(x_all) == 0 or len(y_all) == 0:
    raise ValueError("❌ No images/masks found. Check your dataset paths.")

if len(x_all) != len(y_all):
    raise ValueError(f"❌ Mismatch: {len(x_all)} images vs {len(y_all)} masks")

# ------------------------------
# Balance positive/negative samples
# ------------------------------
if BALANCE:
    print("⚖️ Balancing dataset...")

    pos_indices, neg_indices = [], []
    for i, mask_path in enumerate(y_all):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.reduce_sum(mask).numpy()
        if mask > 0:
            pos_indices.append(i)   # positive mask
        else:
            neg_indices.append(i)   # negative mask

    print(f"Positives: {len(pos_indices)}, Negatives: {len(neg_indices)}")

    # Take 2500 from each for total of 5000
    half_samples = NUM_SAMPLES // 2

    if len(pos_indices) < half_samples:
        raise ValueError(f"❌ Not enough positive samples! Found {len(pos_indices)}, need {half_samples}")
    if len(neg_indices) < half_samples:
        raise ValueError(f"❌ Not enough negative samples! Found {len(neg_indices)}, need {half_samples}")

    np.random.seed(SEED)
    pos_selected = np.random.choice(pos_indices, size=half_samples, replace=False)
    neg_selected = np.random.choice(neg_indices, size=half_samples, replace=False)

    selected_indices = np.concatenate([pos_selected, neg_selected])
    np.random.shuffle(selected_indices)

    x_all = [x_all[i] for i in selected_indices]
    y_all = [y_all[i] for i in selected_indices]

else:
    np.random.seed(SEED)
    indices = np.random.choice(len(x_all), size=min(NUM_SAMPLES, len(x_all)), replace=False)
    x_all = [x_all[i] for i in indices]
    y_all = [y_all[i] for i in indices]

print(f"✅ Using {len(x_all)} samples (balanced={BALANCE})")
assert len(x_all) == NUM_SAMPLES, f"Expected {NUM_SAMPLES} images, got {len(x_all)}"

# ------------------------------
# Train/Val split
# ------------------------------
x_train, x_val, y_train, y_val = train_test_split(
    x_all, y_all, test_size=0.2, random_state=SEED
)

print("Train:", len(x_train), "Val:", len(x_val))

# ------------------------------
# Image parsing (GRAYSCALE)
# ------------------------------
def load_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels=1)  # ✅ Grayscale input
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.cast(img, tf.float32) / 255.0
    return img

def load_mask(path):
    mask = tf.io.read_file(path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, IMAGE_SIZE, method="nearest")
    mask = tf.cast(mask > 127, tf.float32)  # binary mask
    return mask

def augment(img, mask):
    """Data augmentation"""
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    # Random rotation
    if tf.random.uniform(()) > 0.5:
        k = tf.random.uniform(shape=[], minval=1, maxval=4, dtype=tf.int32)
        img = tf.image.rot90(img, k=k)
        mask = tf.image.rot90(mask, k=k)
    return img, mask

def parse_pair(image_path, mask_path, augment_data=False):
    img = load_image(image_path)
    mask = load_mask(mask_path)
    if augment_data:
        img, mask = augment(img, mask)
    return img, mask

# ------------------------------
# Datasets
# ------------------------------
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.map(lambda x, y: parse_pair(x, y, True), num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.shuffle(500).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_ds = val_ds.map(lambda x, y: parse_pair(x, y, False), num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

for imgs, masks in train_ds.take(1):
    print("✅ Image batch:", imgs.shape, "Mask batch:", masks.shape)
    assert imgs.shape[-1] == 1, f"Expected 1 channel, got {imgs.shape[-1]}"

# ------------------------------
# U-Net Model (Grayscale Input)
# ------------------------------
def conv_block(x, filters):
    x = tf.keras.layers.Conv2D(filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.Conv2D(filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    return x

def encoder_block(x, filters):
    c = conv_block(x, filters)
    p = tf.keras.layers.MaxPooling2D((2, 2))(c)
    return c, p

def decoder_block(x, skip, filters):
    x = tf.keras.layers.UpSampling2D((2, 2))(x)
    x = tf.keras.layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

def build_unet(input_shape=(256, 256, 1)):
    """Standard U-Net architecture for grayscale images"""
    inputs = tf.keras.Input(shape=input_shape)

    # Encoder
    c1, p1 = encoder_block(inputs, 64)
    c2, p2 = encoder_block(p1, 128)
    c3, p3 = encoder_block(p2, 256)
    c4, p4 = encoder_block(p3, 512)

    # Bridge
    b = conv_block(p4, 1024)

    # Decoder
    d1 = decoder_block(b, c4, 512)
    d2 = decoder_block(d1, c3, 256)
    d3 = decoder_block(d2, c2, 128)
    d4 = decoder_block(d3, c1, 64)

    # Output
    outputs = tf.keras.layers.Conv2D(1, 1, activation="sigmoid")(d4)

    return tf.keras.Model(inputs, outputs, name="UNet_Grayscale")

print("\n🏗️ Building U-Net model for grayscale images...")
model = build_unet(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
model.summary()

# ------------------------------
# Loss Functions
# ------------------------------
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth))

def bce_dice_loss(y_true, y_pred):
    return tf.keras.losses.binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

# ------------------------------
# Compile & Train
# ------------------------------
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss=bce_dice_loss,
    metrics=["accuracy", dice_coefficient]
)

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        MODEL_NAME,
        save_best_only=True,
        monitor="val_dice_coefficient",
        mode="max",
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        patience=10,
        restore_best_weights=True,
        monitor="val_dice_coefficient",
        mode="max",
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    ),
    tf.keras.callbacks.CSVLogger('training_log.csv')
]

# ------------------------------
# Train
# ------------------------------
print("\n" + "="*60)
print("🚀 Starting Training on 5000 Grayscale Images (Balanced)")
print("="*60)
print(f"Training samples: {len(x_train)}")
print(f"Validation samples: {len(x_val)}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Input shape: (256, 256, 1) - Grayscale")
print(f"Epochs: 60")
print("="*60 + "\n")

history = model.fit(
    train_ds,
    epochs=60,
    validation_data=val_ds,
    callbacks=callbacks,
    verbose=1
)

print("\n" + "="*60)
print("✅ Training completed! Model saved as:", MODEL_NAME)
print("="*60)

# ------------------------------
# Training Summary
# ------------------------------
print("\n📊 Training Summary:")
print(f"   Final Train Loss: {history.history['loss'][-1]:.4f}")
print(f"   Final Val Loss: {history.history['val_loss'][-1]:.4f}")
print(f"   Final Train Dice: {history.history['dice_coefficient'][-1]:.4f}")
print(f"   Final Val Dice: {history.history['val_dice_coefficient'][-1]:.4f}")
print(f"   Best Val Dice: {max(history.history['val_dice_coefficient']):.4f}")
print("\n📁 Saved files:")
print(f"   - {MODEL_NAME}")
print(f"   - training_log.csv")
print("="*60)
# Out:
# Total images: 12047
# Total masks: 12047
# ⚖️ Balancing dataset...
# Positives: 2664, Negatives: 9383
# ✅ Using 5000 samples (balanced=True)
# Train: 4000 Val: 1000
# ✅ Image batch: (30, 256, 256, 1) Mask batch: (30, 256, 256, 1)
#
# 🏗️ Building U-Net model for grayscale images...
# Model: "UNet_Grayscale"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ re_lu[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ re_lu_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ re_lu_4[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ re_lu_6[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ re_lu_8[0][0]     │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ re_lu_9[0][0]     │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 1536)             │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  7,078,400 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ re_lu_10[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ re_lu_11[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 768)              │            │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  1,769,728 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    590,080 │ re_lu_12[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ re_lu_13[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 384)              │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    442,496 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ re_lu_14[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ re_lu_15[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 192)              │            │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │    110,656 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │     36,928 │ re_lu_16[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         65 │ re_lu_17[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,401,345 (119.79 MB)
#  Trainable params: 31,389,569 (119.74 MB)
#  Non-trainable params: 11,776 (46.00 KB)
# ============================================================
# 🚀 Starting Training on 5000 Grayscale Images (Balanced)
# ============================================================
# Training samples: 4000
# Validation samples: 1000
# Batch size: 30
# Input shape: (256, 256, 1) - Grayscale
# Epochs: 60
# ============================================================
#
# Epoch 1/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9523 - dice_coefficient: 0.0154 - loss: 1.2653
# Epoch 1: val_dice_coefficient improved from -inf to 0.01245, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 1442s 10s/step - accuracy: 0.9525 - dice_coefficient: 0.0154 - loss: 1.2646 - val_accuracy: 0.9940 - val_dice_coefficient: 0.0125 - val_loss: 1.2582 - learning_rate: 1.0000e-04
# Epoch 2/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9916 - dice_coefficient: 0.0234 - loss: 1.0938
# Epoch 2: val_dice_coefficient did not improve from 0.01245
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.9916 - dice_coefficient: 0.0234 - loss: 1.0938 - val_accuracy: 0.9940 - val_dice_coefficient: 0.0121 - val_loss: 1.1070 - learning_rate: 1.0000e-04
# Epoch 3/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9855 - dice_coefficient: 0.0374 - loss: 1.0588
# Epoch 3: val_dice_coefficient did not improve from 0.01245
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9855 - dice_coefficient: 0.0374 - loss: 1.0588 - val_accuracy: 0.9940 - val_dice_coefficient: 0.0109 - val_loss: 1.0647 - learning_rate: 1.0000e-04
# Epoch 4/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9824 - dice_coefficient: 0.0530 - loss: 1.0315
# Epoch 4: val_dice_coefficient improved from 0.01245 to 0.05493, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.9824 - dice_coefficient: 0.0530 - loss: 1.0314 - val_accuracy: 0.9824 - val_dice_coefficient: 0.0549 - val_loss: 1.0230 - learning_rate: 1.0000e-04
# Epoch 5/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9820 - dice_coefficient: 0.0665 - loss: 1.0078
# Epoch 5: val_dice_coefficient improved from 0.05493 to 0.06268, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9820 - dice_coefficient: 0.0666 - loss: 1.0078 - val_accuracy: 0.9843 - val_dice_coefficient: 0.0627 - val_loss: 1.0048 - learning_rate: 1.0000e-04
# Epoch 6/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9828 - dice_coefficient: 0.0864 - loss: 0.9793
# Epoch 6: val_dice_coefficient improved from 0.06268 to 0.09912, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.9828 - dice_coefficient: 0.0864 - loss: 0.9793 - val_accuracy: 0.9783 - val_dice_coefficient: 0.0991 - val_loss: 0.9724 - learning_rate: 1.0000e-04
# Epoch 7/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9830 - dice_coefficient: 0.1080 - loss: 0.9518
# Epoch 7: val_dice_coefficient did not improve from 0.09912
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9830 - dice_coefficient: 0.1080 - loss: 0.9518 - val_accuracy: 0.9627 - val_dice_coefficient: 0.0966 - val_loss: 1.0129 - learning_rate: 1.0000e-04
# Epoch 8/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9840 - dice_coefficient: 0.1263 - loss: 0.9279
# Epoch 8: val_dice_coefficient improved from 0.09912 to 0.10158, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.9840 - dice_coefficient: 0.1263 - loss: 0.9279 - val_accuracy: 0.9735 - val_dice_coefficient: 0.1016 - val_loss: 0.9790 - learning_rate: 1.0000e-04
# Epoch 9/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9848 - dice_coefficient: 0.1386 - loss: 0.9120
# Epoch 9: val_dice_coefficient improved from 0.10158 to 0.13569, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 258s 2s/step - accuracy: 0.9848 - dice_coefficient: 0.1387 - loss: 0.9120 - val_accuracy: 0.9889 - val_dice_coefficient: 0.1357 - val_loss: 0.9057 - learning_rate: 1.0000e-04
# Epoch 10/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9856 - dice_coefficient: 0.1639 - loss: 0.8849
# Epoch 10: val_dice_coefficient did not improve from 0.13569
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9856 - dice_coefficient: 0.1640 - loss: 0.8849 - val_accuracy: 0.9899 - val_dice_coefficient: 0.1207 - val_loss: 0.9204 - learning_rate: 1.0000e-04
# Epoch 11/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9873 - dice_coefficient: 0.1837 - loss: 0.8620
# Epoch 11: val_dice_coefficient improved from 0.13569 to 0.13828, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9873 - dice_coefficient: 0.1838 - loss: 0.8619 - val_accuracy: 0.9927 - val_dice_coefficient: 0.1383 - val_loss: 0.8967 - learning_rate: 1.0000e-04
# Epoch 12/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9880 - dice_coefficient: 0.2123 - loss: 0.8326
# Epoch 12: val_dice_coefficient improved from 0.13828 to 0.18485, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.9880 - dice_coefficient: 0.2123 - loss: 0.8325 - val_accuracy: 0.9810 - val_dice_coefficient: 0.1848 - val_loss: 0.8792 - learning_rate: 1.0000e-04
# Epoch 13/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9883 - dice_coefficient: 0.2157 - loss: 0.8285
# Epoch 13: val_dice_coefficient did not improve from 0.18485
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.9883 - dice_coefficient: 0.2157 - loss: 0.8284 - val_accuracy: 0.9855 - val_dice_coefficient: 0.1655 - val_loss: 0.8896 - learning_rate: 1.0000e-04
# Epoch 14/60
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9887 - dice_coefficient: 0.2376 - loss: 0.8074
# Epoch 14: val_dice_coefficient improved from 0.18485 to 0.23397, saving model to unet_pneumo_grayscale_5000.keras
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.9887 - dice_coefficient: 0.2377 - loss: 0.8073 - val_accuracy: 0.9837 - val_dice_coefficient: 0.2340 - val_loss: 0.8235 - learning_rate: 1.0000e-04
# Epoch 15/60
# 116/134 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9894 - dice_coefficient: 0.2555 - loss: 0.7885
